# %% [markdown]
# <a href="https://colab.research.google.com/github/rihanshasawa/EDA_Hotel_Booking_Analysis/blob/main/EDA_Hotel_Booking_Analysis___Rihansh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Hotel Booking ANalysis
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# #### **Introduction** - The Hotel Booking Analysis EDA project is an individual initiative focused on extracting valuable insights from a comprehensive dataset containing hotel booking information. By conducting exploratory data analysis, this project aims to uncover patterns, trends, and factors that significantly influence hotel bookings. The ultimate objective is to utilize the derived insights to assist hotel management and industry stakeholders in making data-driven decisions, optimizing their operations, and elevating customer satisfaction levels. The core focus of this EDA project is to visualize the data comprehensively and derive actionable insights to enhance the user interface, increase bookings, identify key performance indicators, and identify areas for improvement to provide customers with an exceptional experience.
#
#
#
# **Dataset Description** -The Hotel Booking Analysis dataset contains various attributes related to hotel bookings. Each row represents a specific hotel booking, and the columns in the dataset are described below:
#
# (['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date']
#
# This dataset offers a comprehensive view of hotel booking information and provides valuable insights to analyze booking patterns, customer preferences, and factors influencing cancellations and occupancy rates. The data exploration and analysis of this dataset can help optimize hotel operations and enhance the overall guest experience.
#
# **Objective** - The objective of the Hotel Booking Analysis - Exploratory Data Analysis (EDA) project is to gain valuable insights from the dataset containing hotel booking information. Through thorough data exploration and analysis, the project aims to identify patterns, trends, and factors influencing hotel bookings. The ultimate goal is to assist hotel management and industry stakeholders in making data-driven decisions to optimize their operations, improve the user interface, increase bookings, and enhance customer satisfaction.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/rihanshasawa/EDA_Hotel_Booking_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Problem Statement** - The Hotel Booking Analysis EDA project aims to conduct a comprehensive exploratory data analysis on a dataset containing 1,19,390 rows and various attributes related to hotel bookings. The objective is to extract meaningful insights and identify key patterns, trends, and factors influencing hotel bookings. The project seeks to address the following questions:
#
# - **What are the main factors that contribute to hotel booking cancellations, and how can these be minimized to improve hotel revenue and occupancy rates?**
#
# - **How does lead time (the time between booking and arrival) affect booking behavior, and what strategies can be implemented to optimize room availability and pricing?**
#
# -  **Can customer segmentation based on demographics, market segments, or customer types provide valuable insights to personalize services and enhance customer satisfaction?**
#
# -  **What are the most popular room types, meal preferences, and special requests made by guests, and how can hotels use this information to tailor their offerings to meet customer expectations?**
#
# -  **How does the seasonality of hotel bookings influence business performance, and what measures can be taken to address fluctuations in demand?**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The Business Objective of the Hotel Booking Analysis EDA project is to use data analysis to enhance the hotel's performance, improve customer satisfaction, and maximize revenue. By understanding booking patterns, customer preferences, and operational efficiency, the project aims to make informed decisions that optimize resource allocation, personalize services, and implement effective marketing strategies to attract and retain guests. Ultimately, the project seeks to position the hotel as a preferred choice for guests and achieve long-term success in the competitive market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# connect google drive with google colab
from google.colab import drive

drive.mount('/content/drive')

# Import Libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import plotly.express as px
# %matplotlib inline
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_path = "/content/drive/MyDrive/EDA_Dataset_Hotel Booking Analysis/Hotel Bookings.csv"
df = pd.read_csv(file_path)
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset first View
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Total index in the dataset
df.index
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %%
#no. of columns with specific name of the columns in the dataset - columns data are very useful to get the insights for the visualization
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows count
num_rows = df.shape[0]
num_rows
# Out:
# 119390

# %%
# Dataset Columns count
columns_count = df.shape[1]
columns_count
# Out:
# 32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
count_duplicates = df.duplicated().sum()
count_duplicates
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values

#missing_values_columns and percentage of missing values in the columns
missing_columns = ['country', 'agent','company']
missing_values_percentage = (df[missing_columns].isnull().mean())*100

#chnage the colour of bars
bar_colors = ['blue', 'orange', 'green']

#Bar_chart to visulaize the missing values in column
plt.bar(missing_columns, missing_values_percentage,color = bar_colors)

#Labels and titles of Bar_chart
plt.xlabel('Missing_values_Columns')
plt.ylabel('Percentage of Missing Values')
plt.title('Percentage of Missing Values in Columns')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Based on the provided information about the hotel booking dataset, we have a comprehensive dataset consisting of 119,390 rows and 32 columns. Among these columns, 'country', 'agent', and 'company' have missing or null values, with 'country' having 488 missing values, 'agent' having 16,340 missing values, and 'company' having a substantial 112,593 missing values.
#
# With this dataset, we can perform exploratory data analysis (EDA) to gain valuable insights into hotel booking patterns and customer behavior. The dataset contains various features related to bookings, such as 'lead_time', 'arrival_date_year', 'arrival_date_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'meal', 'market_segment', 'deposit_type', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', and 'reservation_status'.
#
# Key areas of analysis could include understanding cancellation trends, seasonal booking patterns, preferred room types, customer segments, and the impact of booking lead time on cancellations. Additionally, investigating the distribution of special requests and their relationship with customer satisfaction could provide valuable insights for the hotel management. However, it's crucial to handle the missing values appropriately and preprocess the data before delving deeper into the analysis to ensure the reliability and accuracy of the insights gained from the EDA process.
#
# Once we handle the missing values, we can dig into the data to find interesting patterns and trends. We'll be able to see things like when most people book their stays, which months are busier for the hotel, and how long people usually wait between booking and arriving. We can also find out which type of hotel room is the most popular and what kind of guests visit the hotel the most.By doing this, we'll gain valuable insights that can help the hotel make better decisions and improve their services for guests. But, it's essential to start by cleaning the data and making sure everything is accurate and reliable, so our analysis is based on solid information.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df['is_canceled']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: is_canceled, Length: 119390, dtype: int64

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. Hotel - This column represents the type of hotel
#
# 2. is_canceled: This variable indicates whether a booking was canceled or not . The description could mention the cancellation rate based on the mean value and highlight the proportion of canceled bookings.
#
# 3. lead_time: The number of days between the booking date and the arrival date. The description could discuss the average lead time and whether there are any extreme values that might need further investigation.
#
# 4. arrival_date_year: The year of the arrival date. The description could mention the range of years present in the dataset and any trends observed over the years.
#
# 5. arrival_date_week_number: The week number of the year for the arrival date. The description could mention any patterns in booking frequency based on the week number.
#
# 6. arrival_date_day_of_month: The day of the month for the arrival date. The description could discuss any patterns related to specific days of the month.
#
# 7. stays_in_weekend_nights: The number of weekend nights the guest stayed or booked to stay at the hotel. The description could mention the average number of weekend nights and whether weekend stays are more common.
#
# 8. stays_in_week_nights: The number of weekday nights the guest stayed or booked to stay at the hotel. The description could discuss the average number of weekday nights and the overall length of stays.
#
# 9. adults, children, babies: These columns represent the number of adults, children, and babies in the booking, respectively. The description could discuss the typical group size of guests (average values) and any variations in the number of children and babies.
#
# 10. is_repeated_guest: This column indicates if the guest is a repeated guest or not. The description could discuss the proportion of repeated guests and their potential impact on bookings.
#
# 11. previous_cancellations: The number of previous bookings canceled by the guest. The description could discuss the frequency of previous cancellations and its relevance to current bookings.
#
# 12. previous_bookings_not_canceled: The number of previous bookings not canceled by the guest. The description could mention any patterns in guests' history of not canceling bookings.
#
# 13. booking_changes: The number of changes made to the booking. The description could discuss the frequency of booking modifications and their impact on cancellations.
#
# 14. agent : This columns represent the money received by the agent. the description represents the percentage of money. highest rate and lowest rate of the agent.
#
# 15. company - This column reprent the total money. max money, lowest money and mean money received by the company and also represents the trends to analyse the profit and loss structure
#
# 16. days_in_waiting_list: The number of days the booking was in the waiting list before confirmed. The description could discuss the average waiting time and any patterns related to waitlisted bookings.
#
# 17. adr: The average daily rate of the booking. The description could discuss the average cost per night and any variations in pricing.
#
# 18. required_car_parking_spaces: The number of car parking spaces required by the guest. The description could discuss the need for parking spaces among guests.
#
# 19. total_of_special_requests: The total number of special requests made by the guest. The description could discuss the frequency of special requests and the most common types of requests.
#
# 20. meal: This column represents the type of meal booked (e.g., Bed & Breakfast, Half-board, etc.). The description could discuss the different meal types and their popularity among guests.
#
# 21. country: This column contains the country code of the guests. The description could mention the number of unique countries represented in the dataset and any insights into the distribution of guests from different countries.
#
# 22. market_segment: This column represents the market segment designation (e.g., Online Travel Agent, Corporate, etc.). The description could discuss the most common market segments and their significance.
#
# 23. distribution_channel: This column indicates the booking distribution channel (e.g., Direct, Travel Agent). The description could mention the different distribution channels and their usage.
#
# 24. reserved_room_type: This column represents the type of room reserved. The description could discuss the different room types and their popularity among guests.
#
# 25. assigned_room_type: This column represents the type of room actually assigned to the guest. The description could discuss any differences between reserved and assigned room types.
#
# 26. deposit_type: This column indicates the type of deposit made for the booking (e.g., No Deposit, Non-Refundable). The description could discuss the proportion of different deposit types and their relationship with cancellations.
#
# 27. customer_type: This column represents the type of customer (e.g., Transient, Contract, Group). The description could discuss the distribution of customer types and their booking behavior.
#
# 28. reservation_status: This column indicates the status of the reservation (e.g., Check-Out, Canceled, No-Show). The description could discuss the distribution of reservation statuses and any insights related to cancellations or no-shows.
#
# 29. reservation_status_date: This column represents the date on which the reservation status was set. The description could discuss any patterns related to reservation status changes over time.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable. - # Understand the unique values in the dataframe to understand the data

# %%
df['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
df['is_canceled'].unique()
# Out:
# array([0, 1])

# %%
df['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017])

# %%
df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
df['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
df['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
df['is_repeated_guest'].unique()
# Out:
# array([0, 1])

# %%
df['customer_type'].unique()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
df['deposit_type'].unique()
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %%
df['reservation_status'].unique()
# Out:
# array(['Check-Out', 'Canceled', 'No-Show'], dtype=object)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# In the initial state of our hotel booking analysis, we obtained a dataset with 119,390 rows and 32 columns, representing various aspects of hotel bookings. However, the data had some issues that needed attention. Missing values were present in 'country', 'agent', and 'company' columns, and there were duplicate entries as well. To ensure accurate analysis, we cleaned the data by using the following steps :
# 1. Remove duplicate rows
# 2. Handling Missing values
# 3. Convert columns to appropriate datatypes
# 4. Adding important columns - total guests and total nights stayed

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# **Step 1 - Removing Duplicate Rows**

# %%
# First step is to see the total number of duplicate rows
df[df.duplicated()].shape
# Out:
# (31994, 32)

# %%
# Removing Duplicate values
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# **Step 2 - Handling Missing values**

# %%
# Total number of missing values in the DataFrame
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %% [markdown]
# In our hotel booking analysis, the 'company' and 'agent' columns contain data related to the company and agent numbers associated with each booking. However, it is possible that some customers did not book the hotel through any specific agent or company, resulting in missing or null values in these columns. To handle this scenario, we will replace these null values with 0. This approach allows us to retain the distinction between bookings made through agents or companies and those made without any specific agent or company involvement. By imputing 0 for the missing values, we ensure that the data remains informative and ready for further analysis without compromising the integrity of the original dataset.
#
# Next column with missing value is 'country'. This column represents the country of oriigin of customer. So, We will replace the null_values with the 'Unknown' in the country column

# %%
# Replacing the missing_values / null_values with 0 in company & agent columns
df['company'].fillna(0, inplace=True)
df['agent'].fillna(0, inplace=True)

# Replacing the missing_values in country column with 'Unknown'
df['country'].fillna('Unknown', inplace=True)

# %% [markdown]
# There are 4 null_values in children column....So, We will replace the null values under this column with mean value of children.

# %%
df['children'].fillna(df['children'].mean(), inplace = True)

# %%
#CHecing the all null_values are removed or not
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# Now, There are some rows with total number of adults, children or babies equal to zero. So we will remove such rows.

# %%
# checking the sum of adults, children and babies is zero or not
df[df['adults']+df['babies']+df['children'] == 0].shape
# Out:
# (166, 32)

# %% [markdown]
# There are 166 rows with total number of adults, children or babies equal to zero, So we will remove such rows

# %%
df.drop(df[df['adults']+df['babies']+df['children'] == 0].index, inplace = True)

# %% [markdown]
# **Step 3 - Convert columns to appropriate datatypes**

# %%
#Converting datatype of columns 'children', 'company' and 'agent' from float to int.
df['children'] = df['children'].astype(int)
df['company'] = df['company'].astype(int)
df['agent'] = df['agent'].astype(int)

# %%
# Convert date columns to datetime data type
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %% [markdown]
# **Step 4 - Adding important columns - total guests and total nights stayed**

# %%
# Adding total_guests column = adults + children + babies
df['total_guests'] = df['adults'] + df['children'] + df['babies']

# Adding total_nights_stayed = stayed in weekend nights + stayed in week nights
df['total_nights_stayed'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# In our data wrangling process for the hotel booking analysis, we performed several manipulations to prepare the dataset for in-depth exploration. Here are the key steps we took and the insights we found:
#
# - Remove Duplicate Rows: We identified and removed any duplicate entries in the dataset to ensure data integrity. This step allowed us to focus on unique booking records and avoid any repetition in our analysis.
#
# - Handling Missing Values: We addressed missing values in columns like 'country', 'agent', and 'company'. For 'country', we retained the missing values as they represented cases where customers might not have specified a country during the booking process. However, for 'agent' and 'company', which represented agent and company numbers, respectively, we filled the missing values with 0, as it indicated that those bookings were not made through any specific agent or company.
#
# - Convert Columns to Appropriate Datatypes: We converted the 'children', 'company', and 'agent' columns from float to integer data type, as they represented whole numbers. This conversion allowed us to work with these columns more efficiently in subsequent analyses.
#
# - Adding Important Columns: We introduced two new columns, 'total guests' and 'total nights stayed', to gain deeper insights into booking patterns. By summing up the number of 'adults', 'children', and 'babies', we calculated the total number of guests for each booking. Similarly, by combining 'stays_in_weekend_nights' and 'stays_in_week_nights', we derived the total nights stayed.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

#custom colors for the bars
colors = ['skyblue', 'lightgreen']

# bar plot with custom colors
plt.bar(df['hotel'].value_counts().index,df['hotel'].value_counts().values, color=colors)
plt.xlabel('Hotel Type')
plt.ylabel('Number of Bookings')
plt.title('Distribution of Bookings by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  chose the bar chart for visualizing the distribution of bookings based on the 'hotel' column because it is a clear and effective way to compare the number of bookings in different categories (City Hotel and Resort Hotel). The chart's simplicity allows for easy identification of the booking patterns in each hotel type, making it ideal for this scenario.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart reveals that City Hotels have significantly higher bookings (50k+) compared to Resort Hotels (30-40k bookings). This indicates that City Hotels are more popular among customers or attract a larger number of guests compared to Resort Hotels. It also suggests that the demand for City Hotels might be higher, and there could be factors contributing to their popularity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the chart can have a positive business impact. Understanding the higher demand for City Hotels allows the management to focus on enhancing services, amenities, and marketing strategies for these hotels to further capitalize on their popularity.
#
# The bookings of the Resort Hotel is lower then the city hotel. So, need to do more marketing, provide more offers, family vacation discounts for resort hotel and also need to improve the service if necessary for resort hotel to increase the bookings
# Additionally, we can analyze the factors that attract more bookings to City Hotels and replicate those successful aspects in Resort Hotels, potentially increasing their bookings as well.

# %% [markdown]
# #### Chart - 2

# %%
# Revenue_Based_Analysis

# Grouping by hotel and calculating average adr
grouped_by_hotel = df.groupby('hotel')
avg_adr_by_hotel = grouped_by_hotel['adr'].mean().reset_index()

# Creating the bar plot
plt.figure(figsize=(6, 4))
sns.barplot(x='hotel', y='adr', data=avg_adr_by_hotel, palette=['skyblue', 'lightgreen'])
plt.xlabel('Hotel Type')
plt.ylabel('Average Daily Rate (ADR)')
plt.title('Average Daily Rate (ADR) by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  picked the specific bar chart to compare the average daily rate (ADR) between the two types of hotels (City Hotel and Resort Hotel) because it provides a clear and visual representation of the ADR for each category, making it easy to find out which hotel is making more revenue

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows that the average daily rate for the City Hotel is slightly higher than the average daily rate for the Resort Hotel. This indicates that, on average, guests pay more per day for staying in the City Hotel compared to the Resort Hotel.
# it means City hotel is making slightly more revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact - The gained insight from the chart can be valuable for the hotel management to understand their pricing strategies and revenue generation. The City Hotel may have an opportunity to position itself as a more upscale or luxurious option, attracting guests who are willing to pay higher rates for enhanced services and amenities.
#
# On the other hand, the Resort Hotel might focus on marketing its value propositions, such as its scenic location, recreational activities, and family-friendly facilities, to attract visitors seeking a more affordable vacation. There is also less bookings in Resort Hotel, so need to increase the bookings as well to generate more revenue in Resort Hotels

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# Distribution of hotel bookings based on the market segment.

plt.figure(figsize=(12, 6))

# Plot for City Hotel bookings by market segment
plt.subplot(1, 2, 1)
sns.countplot(x='market_segment', data=df[df['hotel'] == 'City Hotel'], palette='pastel')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.title('City Hotel - Bookings by Market Segment')
plt.xticks(rotation=45, ha='right')

# Plot for Resort Hotel bookings by market segment
plt.subplot(1, 2, 2)
sns.countplot(x='market_segment', data=df[df['hotel'] == 'Resort Hotel'], palette='pastel')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.title('Resort Hotel - Bookings by Market Segment')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this plot, which consists of two side-by-side bar charts, because it allows me to compare the number of bookings for each hotel type based on different market segments effectively. By using this plot, I can visually analyze and compare the booking patterns in various market segments for both City Hotel and Resort Hotel simultaneously. This comparison is helpful in identifying potential trends, popular market segments, and any disparities between the two hotel types. It provides a comprehensive view of the distribution of bookings, aiding in making data-driven decisions, formulating marketing strategies, and understanding customer preferences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There are following Insights from the chart -
# - Online TA segment has the highest number of bookings in both type of hotels
# - Approx 40k bookings by online TA in city Hotels
# - No of bookings by corporate segment is very less in both hotels
# - No of booking by oflline TA/TO is less in resort hotels as compare to city hotels
# - Groups booking is also less in resort hotels as compare to city hotels

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact
# - Online TA Segment Bookings: The highest number of bookings from the Online Travel Agency (TA) segment suggests that online booking platforms are popular among customers. This insight can help hotels focus on enhancing their online presence, optimizing their websites for booking, and improving their partnerships with online travel agencies to attract more customers.
#
# - Low Corporate Segment Bookings: The low number of bookings from the corporate segment may indicate that the hotel's offerings and services may not be well-aligned with the preferences and requirements of corporate travelers. Hotels can explore corporate partnerships, offer special packages or amenities for business travelers, and improve facilities that cater to their needs to increase corporate segment bookings.
#
# - Offline TA/TO Bookings: The relatively lower number of bookings from offline Travel Agents/ Tour Operators (TA/TO) in resort hotels compared to city hotels suggests a potential area of improvement. Hotels can collaborate more closely with offline TA/TOs and offer attractive packages for resort destinations to boost bookings from this segment.
#
# - Groups Booking in Resort Hotels: The lower number of group bookings in resort hotels compared to city hotels may indicate that resort hotels need to work on marketing strategies and offers that specifically target group travelers. Implementing group discounts, promoting group-friendly activities, and improving group accommodation facilities can help attract more bookings from this segment.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization
#distribution of lead time for both hotel types

lead_time_data = df[['hotel', 'lead_time']]

# Plotting the distribution of lead time for each hotel type
plt.figure(figsize=(10, 6))
sns.boxplot(x='hotel', y='lead_time', data=lead_time_data, palette='Set3')
plt.xlabel('Hotel Type')
plt.ylabel('Lead Time (Days)')
plt.title('Distribution of Lead Time for City and Resort Hotels')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the box plot to analyze the distribution of lead time for different hotel types (city and resort hotels) because it effectively presents the spread of data, including the median, quartiles, and potential outliers. The box plot allows us to compare the lead time distribution between two categorical groups (hotel types) and identify any variations in booking patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The median lead time for city hotels is slightly higher than that of resort hotels. This suggests that, on average, customers tend to book city hotels a bit earlier than resort hotels.
#
# - The interquartile range (IQR), represented by the box, shows that the middle 50% of lead times for both hotel types fall within a range of approximately 100 days. This indicates that most bookings are made within a similar timeframe, regardless of the hotel type.
#
# - City hotels have more outliers on the upper side of the box plot, which means there are more instances of extremely long lead times for city hotels compared to resort hotels. This could indicate that some customers book city hotels well in advance, possibly due to high demand or specific events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the chart can indeed help create a positive business impact for the hotel industry:
#
# Understanding that city hotels have a slightly higher median lead time and more outliers on the upper side can help hotel management optimize their revenue management strategies. By offering early bird discounts, special promotions, or other incentives for guests who book in advance, city hotels can encourage more early bookings, leading to better revenue planning and occupancy management.
#
# *Negative Growth insights:
#
# The presence of outliers on the upper side of the lead time distribution for city hotels may indicate instances of customers making last-minute bookings. This might suggest that city hotels face intense competition, and some customers may be hesitant to make reservations in advance due to flexible travel plans or uncertainty. This could lead to potential negative growth if city hotels fail to effectively differentiate themselves from competitors or fail to provide compelling reasons for customers to book early.
#
# The box chart's limited range of approximately 100 days for both hotel types might highlight a potential risk of overbooking or operational challenges, especially during peak seasons. Overbooking can lead to negative guest experiences and impact customer satisfaction if hotels are unable to accommodate all booked guests. To mitigate this risk, hotels need to closely monitor booking trends, forecast demand accurately, and implement robust reservation management systems.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# Calculate the percentage of canceled bookings for each hotel type
total_bookings_by_hotel = df.groupby('hotel')['is_canceled'].count()
canceled_bookings_by_hotel = df.groupby('hotel')['is_canceled'].sum()

percentage_canceled = (canceled_bookings_by_hotel / total_bookings_by_hotel) * 100

# Create a DataFrame to store the data
cancellation_data = pd.DataFrame({'Hotel Type': percentage_canceled.index,'Percentage Canceled': percentage_canceled.values})

# Plot the bar chart
sns.barplot(x='Hotel Type',y='Percentage Canceled',data=cancellation_data,color='red')
plt.xlabel('Hotel Type')
plt.ylabel('Percentage of Canceled Bookings')
plt.title('Percentage of Canceled Bookings by Hotel Type')
plt.show()

cancellation_data
# Out:
#      Hotel Type  Percentage Canceled
# 0    City Hotel            30.099110
# 1  Resort Hotel            23.483331

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the specific bar chart to visualize the percentage of canceled bookings for each hotel type because it effectively displays the comparison between the two categories (city hotel and resort hotel) in a clear and straightforward manner. The bar chart allows us to easily see the difference in the percentage of canceled bookings between the two types of hotels and helps identify any potential patterns or trends. It also enables a quick comparison between the two categories, making it easy to draw insights and understand the impact of cancellations on each hotel type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The percentage of canceled bookings is higher for the City Hotel (41.79%) compared to the Resort Hotel (27.77%). This indicates that a larger proportion of bookings in the City Hotel are being canceled, suggesting that there may be factors specific to the City Hotel that are influencing guests to cancel their reservations more frequently.
#
# - The higher cancellation rate for the City Hotel could be attributed to various factors such as the nature of the guests' trips, business-related bookings, or more flexible travel plans. On the other hand, the lower cancellation rate for the Resort Hotel might indicate that guests booking resorts may have more fixed vacation plans, leading to fewer cancellations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# - By identifying the factors contributing to higher cancellation rates in the City Hotel, the marketing team can tailor their promotions and offers to attract more committed guests.
#
# - Analyzing the reasons behind cancellations can help the hotel staff proactively address customer concerns, leading to improved guest satisfaction and higher customer retention. Providing personalized services and addressing potential issues promptly can enhance guest loyalty.
#
# - Reducing cancellation rates can lead to increased revenue stability for the City Hotel. A lower number of cancellations means more guaranteed bookings, allowing the hotel to optimize room inventory, minimize revenue losses, and enhance revenue predictability.
#
# Negative Growth Insights: The higher cancellation rate in the City Hotel might lead to negative growth if not addressed appropriately. Several potential negative impacts include:
# - Revenue Loss
# - Operational Challenges
# - Reputation Damage

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# Calculate the percentage of each meal type in the dataset
meal_counts = df['meal'].value_counts(normalize=True) * 100

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(meal_counts, labels=meal_counts.index, autopct='%1.1f%%',colors=['lightgreen', 'skyblue', 'lightcoral', 'orange', 'pink'])
plt.title('Distribution of Bookings by Meal Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the pie chart for visualizing the distribution of bookings across different meal types because The pie chart allows us to quickly compare the popularity of different meal types at a glance. Each slice of the pie represents a meal type, and the size of the slice corresponds to its percentage in the dataset. The labels on the slices make it easy to identify and understand each category.
#
# Using a pie chart also makes it straightforward to observe any major differences in the distribution of meal types, as well as identify any dominant or less popular meal plans.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The majority of bookings (approximately 77.4%) have opted for the "Bed and Breakfast" (BB) meal plan, indicating that this meal type is the most popular choice among guests.
#
# - The "Half Board" (HB) meal plan is the second most common option, accounting for around 12.1% of bookings.
#
# - A smaller proportion of bookings (approximately 8.8%) have chosen the "Self Catering" (SC) meal plan.
#
# - There is a small percentage (around 1%) of bookings with "Undefined" meal types, which might be due to missing or unspecified meal information.
#
# - The "Full Board" (FB) meal plan has the lowest adoption rate, making up only 0.7% of the bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact :
# - Knowing that the majority of guests prefer the "Bed and Breakfast" (BB) meal plan allows hotels to focus on providing quality breakfast options, potentially improving guest satisfaction and loyalty.
#
# - With insights into the popularity of different meal plans, hotels can optimize their meal planning and inventory management. They can ensure they have sufficient resources and ingredients for the most popular meal types, reducing wastage and operational costs.
#
# - Hotels can use this information to design targeted marketing campaigns and promotions for specific meal plans. Offering discounts or special packages for the most preferred meal options may attract more bookings and increase revenue.
#
# Negative Growth Insights:
# There are no specific insights from the pie chart that directly lead to negative growth. However, having a small percentage of "Undefined" meal types (around 1%) could potentially cause some operational challenges. If the hotel does not have a clear understanding of the meal preferences of these guests, it may lead to inefficiencies in meal planning, resulting in higher costs or lower guest satisfaction.
#
# To mitigate this, hotels can implement strategies to encourage guests to specify their meal preferences at the time of booking or check-in.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Distribution of bookings based on the "reserved_room_type"

# Plotting the count plot
plt.figure(figsize=(10, 6))
sns.countplot(x='reserved_room_type', hue='hotel', data=df, palette='pastel')
plt.xlabel('Reserved Room Type')
plt.ylabel('Number of Bookings')
plt.title('Distribution of Bookings by Reserved Room Type')
plt.legend(title='Hotel Type', loc='upper right', labels=['Resort Hotel', 'City Hotel'])

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  chose the count plot to visualize the distribution of bookings based on the "reserved_room_type" column because it effectively displays the number of bookings for each room type in a clear and easy-to-understand manner. This chart is especially useful when dealing with categorical data like room types and provides valuable insights into which room types are more popular among guests at both types of hotels.
#
#  It helps stakeholders make data-driven decisions related to room management, pricing strategies, and promotional activities, which can lead to a positive business impact by optimizing revenue and customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The majority of bookings in both City Hotel and Resort Hotel are of room type 'A', which indicates that this room type is the most preferred choice among customers.
# - Room type 'D' is the second most common choice for bookings in City Hotel, whereas in Resort Hotel, it is room type 'D' followed by room type 'E'.
# - Room types 'F', 'G', and 'E' also have a considerable number of bookings in both hotels, although they are less common compared to room type 'A' and 'D'.
# - Some room types are exclusive to one hotel type. For example, room types 'H', 'L', and 'C' are only available in Resort Hotel, while room type 'B' is present in both hotels but has very few bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact :
# - Optimal Inventory Management: By knowing the most preferred room types, hotels can ensure that they have an adequate inventory of these rooms to meet the demand.
#
# - Pricing Strategy: Knowing the popularity of room types can also help hotels set appropriate pricing. They can price the more popular room types slightly higher, maximizing revenue, while offering attractive deals for less popular room types to increase their demand.
#
# - Marketing and Promotions: Hotels can use this information for targeted marketing and promotions.
#
# - Room Allocation and Renovation: Based on the insights, hotels can allocate their resources and investments wisely. They can prioritize the maintenance and renovation of popular room types to ensure they are in top condition, attracting more guests.
#
# As for negative growth, one potential concern could be the underutilization of less popular room types. If certain room types consistently receive very few bookings, it may lead to revenue loss and inefficiency in resource allocation. However, by offering targeted promotions and packages for these room types, hotels can try to improve their utilization and mitigate any negative impact.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Distribution of the number of stays in weekend nights and stays in week nights separately for both city hotels and resort hotels using Box Plots

# Filter data for city hotels and resort hotels
city_hotel_data = df[df['hotel'] == 'City Hotel']
resort_hotel_data = df[df['hotel'] == 'Resort Hotel']

# Create box plot for stays in weekend nights
plt.figure(figsize=(8, 6))
sns.boxplot(x='hotel', y='stays_in_weekend_nights', data=df, palette='Set1')
plt.xlabel('Hotel Type')
plt.ylabel('Stays in Weekend Nights')
plt.title('Distribution of Stays in Weekend Nights for City and Resort Hotels')
plt.show()

# Create box plot for stays in week nights
plt.figure(figsize=(8, 6))
sns.boxplot(x='hotel', y='stays_in_week_nights', data=df, palette='Set2')
plt.xlabel('Hotel Type')
plt.ylabel('Stays in Week Nights')
plt.title('Distribution of Stays in Week Nights for City and Resort Hotels')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the box plot to visualize the distribution of the number of stays in weekend nights and stays in week nights separately for both city hotels and resort hotels because it is an effective way to compare the distribution of a numerical variable across different hotel type.
#
# we can easily identify differences in the distribution of stays in weekend nights and week nights between city hotels and resort hotels. It helps us understand if there are any significant variations in the number of stays between the two hotel types, and it also highlights any potential outliers that might need further investigation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# stays in Weekend Nights:
#
# - Both city hotels and resort hotels have a similar range of stays in weekend nights, with the box extending below 2.5. This indicates that most of the bookings have stays of 2 nights or less during the weekends.
# - However, the number of outliers in resort hotels is significantly higher than in city hotels, with some reservations having stays of more than 17.5 nights. This suggests that there are some extreme cases of longer weekend stays in resort hotels.
# - The presence of such outliers might indicate extended vacation stays or special events in resort hotels, which could be an opportunity for targeted marketing and promotions to attract customers seeking longer weekend getaways.
#
# Stays in Week Nights:
#
# - The median and interquartile range of stays in week nights are similar for both city hotels and resort hotels, with the box extending below 5. This suggests that the majority of bookings have stays of 5 nights or less during weekdays.
# - The city hotel's box is slightly lower than the resort hotel's box, indicating that the median stay duration for week nights is slightly lower in city hotels.
# - The presence of higher outliers in resort hotels (up to 50 nights) compared to city hotels (up to 30 nights) suggests that resort hotels might attract guests who stay for longer durations during weekdays.
# This insight could be leveraged by marketing teams to tailor promotions or business strategies to attract guests seeking extended weekday stays, such as business travelers, long-term guests, or those attending conferences and events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# - The insights from the box plot can help the hotel management and marketing teams better understand the booking patterns and preferences of their guests.
# - Targeted marketing campaigns can be designed to attract guests seeking longer weekend stays in resort hotels, potentially increasing revenue and occupancy during weekends.
# - Tailoring promotions and services for guests looking for extended weekday stays in resort hotels can lead to increased bookings from business travelers and other long-term guests, positively impacting revenue and customer loyalty
#
# Negative Growth:
#
# The presence of outliers with exceptionally long stays in both weekend nights and week nights could also indicate potential booking errors or data issues. Hotels should carefully review such cases to ensure data accuracy and avoid negative impacts on customer satisfaction due to incorrect bookings.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Top 10 countries with the Most Guests

# Grouping data by country and calculating total guests from each country
guests_by_country = df.groupby('country')['total_guests'].sum().reset_index()

# Sorting data in descending order of total guests
guests_by_country = guests_by_country.sort_values(by='total_guests', ascending=False)

# Plotting the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='total_guests', data=guests_by_country.head(10))
plt.xlabel('Country')
plt.ylabel('Total Guests')
plt.title('Top 10 Countries with the Most Guests')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the bar chart to visualize the number of guests from each country because it is an effective way to compare the total guests from different countries at a glance. The bar chart allows us to easily identify the countries with the highest number of guests, as the length of the bars directly represents the total guest count. Additionally, by showing only the top 10 countries, we can focus on the most significant contributors to the total number of guests, making the chart more informative and easy to interpret.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Portugal (PRT) has the highest number of guests with more than 80,000 bookings, indicating its popularity as a tourist destination.
#
# - United Kingdom (GBR) and France (FRA) have around 20,000+ bookings, making them significant contributors to the total number of guests.
#
# - Spain (ESP) has below 20,000 bookings, suggesting that it attracts a relatively lower number of guests compared to Portugal, the UK, and France.
#
# - Germany (DEU) has even fewer bookings than Spain, indicating a lower demand for accommodations from German guests.
#
# - Italy (ITA) has fewer bookings than Germany, indicating that it may not be as popular among hotel guests.
#
# - Ireland (IRL) has even fewer bookings than Italy, suggesting a lower demand from Irish guests.
#
# - Belgium (BEL), Brazil (BRA), and the USA have the lowest number of bookings among the top 10 countries, indicating relatively lower demand from guests in these countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights that lead to positive business impact:
#
# - The high number of guests from Portugal, the UK, and France presents an opportunity for hotel businesses to cater to these markets and offer targeted promotions and services.
#
# Insights that may lead to negative growth:
#
# - The lower number of guests from countries like Germany, Italy, Ireland, Belgium, Brazil, and the USA may suggest challenges in attracting guests from these regions. Hotels may need to explore marketing strategies or tailored offerings to attract guests from these countries and drive growth.

# %% [markdown]
# #### Chart - 10

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already performed data wrangling and added the 'arrival_date_month' and 'total_guests' columns

#

# Group the data by 'arrival_date_month' and calculate the total number of guests for each month
monthly_guests = df.groupby('arrival_date_month')['total_guests'].sum().reindex(month_order)

# Create a line chart to analyze the data monthly
plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_guests.index, y=monthly_guests.values, marker='o')
plt.title('Total Number of Guests by Month')
plt.xlabel('Month')
plt.ylabel('Total Number of Guests')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Chart - 10 visualization code
#  line chart to analyze the data monthly

#Define the order of months for proper sorting in the line chart
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Filter data for city hotel
city_hotel_data = df[df['hotel'] == 'City Hotel']
# Group data by 'arrival_date_month' and calculate total bookings for each month
city_monthly_bookings = city_hotel_data.groupby('arrival_date_month')['hotel'].count().reset_index()
city_monthly_bookings = city_monthly_bookings.rename(columns={'hotel': 'total_bookings'})
# Sort the data by month
city_monthly_bookings['arrival_date_month'] = pd.Categorical(city_monthly_bookings['arrival_date_month'], categories= month_order, ordered=True)
city_monthly_bookings = city_monthly_bookings.sort_values('arrival_date_month')

# Filter data for resort hotel
resort_hotel_data = df[df['hotel'] == 'Resort Hotel']
# Group data by 'arrival_date_month' and calculate total bookings for each month
resort_monthly_bookings = resort_hotel_data.groupby('arrival_date_month')['hotel'].count().reset_index()
resort_monthly_bookings = resort_monthly_bookings.rename(columns={'hotel': 'total_bookings'})
# Sort the data by month
resort_monthly_bookings['arrival_date_month'] = pd.Categorical(resort_monthly_bookings['arrival_date_month'], categories= month_order, ordered=True)
resort_monthly_bookings = resort_monthly_bookings.sort_values('arrival_date_month')

# Create the line chart for city hotel
plt.figure(figsize=(10, 6))
sns.lineplot(x='arrival_date_month', y='total_bookings', data=city_monthly_bookings, marker='o', label='City Hotel')
plt.xlabel('Month')
plt.ylabel('Total Bookings')
plt.title('Monthly Distribution of Total Bookings for City Hotel')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Create the line chart for resort hotel
sns.lineplot(x='arrival_date_month', y='total_bookings', data=resort_monthly_bookings, marker='o', label='Resort Hotel')
plt.xlabel('Month')
plt.ylabel('Total Bookings')
plt.title('Monthly Distribution of Total Bookings for Resort Hotel')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the line chart to analyze the monthly distribution of total bookings for both hotels separately because it effectively shows the trend of bookings over time. Line charts are particularly useful when we want to visualize how a variable changes with respect to another variable, in this case, the total bookings over different months.
#
# The line chart enables us to see if there are any specific months when bookings are higher or lower for each hotel type. It can also help us identify any potential seasonal trends or fluctuations in booking behavior, which can be valuable for making business decisions and optimizing resources accordingly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Seasonal Variation: Both hotels experience fluctuations in the number of guests throughout the year. The highest number of guests are observed in August, which might indicate the peak vacation season. Conversely, January sees the lowest number of guests, likely due to the off-peak winter season.
#
# - Differences Between Hotels: The city hotel consistently attracts more guests than the resort hotel in all months. This difference in guest numbers could be attributed to factors such as location, amenities, and target market.
#
# - Popular Months: April, May, and June also show a good number of guests in both hotels, suggesting that these months are popular for tourism and bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact: The gained insights can have a positive business impact for both hotels. By understanding the seasonal patterns, hotels can optimize their marketing strategies and pricing models to attract more guests during peak months and offer special promotions during slower months to drive bookings.
#
# Negative Growth: While the analysis doesn't explicitly reveal negative growth, the lower number of guests in certain months for the resort hotel may indicate a need for targeted marketing efforts or improvements in offerings to attract more guests during those periods.
#
# In conclusion, the insights from the line chart analysis can help hotels make data-driven decisions to enhance their business strategies, improve guest experiences, and maximize revenue throughout the year. By leveraging this information, hotels can better align their operations with seasonal demands and work towards sustainable growth.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Top 10 agents who made the highest number of bookings

# Group data by agent and calculate the number of bookings made by each agent
agent_bookings = df['agent'].value_counts().reset_index()
agent_bookings.columns = ['agent', 'num_bookings']

# Sort agents by the number of bookings in descending order
agent_bookings = agent_bookings.sort_values(by='num_bookings', ascending=False)

# Select the top 10 agents with the highest number of bookings
top_10_agents = agent_bookings.head(10)

# Plot the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x='agent', y='num_bookings', data=top_10_agents, palette='viridis')
plt.xlabel('Agent')
plt.ylabel('Number of Bookings')
plt.title('Top 10 Agents with Highest Number of Bookings')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the bar chart to visualize the top 10 agents with the highest number of bookings because it effectively displays the comparison between different agents in terms of their booking counts. The bar chart is suitable for this scenario as it allows us to easily identify the agents with the highest booking activity and make quick comparisons between them. The bars provide a clear representation of the number of bookings for each agent, making it easy to spot the top performers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# These all are the TOp 10 agents in the Hotel Industry to book highest numbers of bookings.
# Also in the top 10 agents, We identified that
# - Agent ID 9 has the highest number of bookings, exceeding 25,000 bookings. This agent is the top performer and contributes significantly to the hotel's business.
#
# - Agents with IDs 240 and 0 have bookings above 10,000, making them high-performing agents who bring in a substantial number of customers.
#
# - Agents with IDs 1, 7, 8, 14, 28, 241, and 250 have bookings ranging below 5,000. These agents are performing well but have relatively lower booking counts compared to the top agents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart can help create a positive business impact. Identifying the top-performing agents (ID 9, 240, and 0) allows the hotel management to focus on strengthening their partnership and providing them with better incentives and support. Building strong relationships with these top agents can lead to increased bookings and revenue for the hotel.
#
# The insights gained from this chart can help create a positive business impact. Identifying the top-performing agents (ID 9, 240, and 0) allows the hotel management to focus on strengthening their partnership and providing them with better incentives and support. Building strong relationships with these top agents can lead to increased bookings and revenue for the hotel.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# total revenue for both types of hotel

# Calculate total revenue by multiplying 'adr' and total nights stayed for each booking
df['total_revenue'] = df['adr'] * (df['stays_in_weekend_nights'] + df['stays_in_week_nights'])

# Group the data by 'hotel' and calculate the total revenue for each hotel
revenue_by_hotel = df.groupby('hotel')['total_revenue'].sum().reset_index()

# Create a bar chart to compare total revenue for each hotel
plt.figure(figsize=(8, 6))
sns.barplot(x='hotel', y='total_revenue', data=revenue_by_hotel)
plt.title('Total Revenue by Hotel')
plt.xlabel('Hotel')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the bar chart to visualize the total revenue by hotel type because it effectively compares the revenue generated by each type of hotel in a clear and straightforward manner. The bar chart allows for easy comparison between the two categories (City Hotel and Resort Hotel) and helps identify any significant differences in revenue.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart, we can observe that the revenue generated by the City Hotel is higher than 1.75 Million and the revenue generated by the Resort Hotel is higher than 1.50 Million. This suggests that both types of hotels are generating significant revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Positive Business Impact: The insight that both types of hotels are generating substantial revenue indicates a positive business impact. It suggests that there is a strong demand for accommodations in both city and resort locations, leading to successful revenue generation for the hotels.
#
# - Potential for Growth: The fact that both hotels are surpassing the 1.50 million revenue mark implies that there is potential for further growth in the future. The hotels can focus on strategic marketing, enhancing guest experiences, and optimizing their operations to attract more customers and increase revenue.
#
# - Competitive Advantage: City hotels, in particular, have a slight edge over resort hotels, as their revenue is higher than 1.75 million. This indicates that city hotels may have a competitive advantage in terms of attracting business travelers, events, and conferences, which contribute to their higher revenue.
#
# Negative Growth:
# Based on the provided data, there is no insight suggesting negative growth for either hotel type. Both hotels are performing well in terms of revenue generation, and there are no indicators of declining revenue at this point.
#
# Overall, the gained insights indicate a positive business outlook for both city and resort hotels. The revenue generated by both types of hotels shows a promising trend, and there is potential for further growth and success in the hospitality industry. However, to maintain this positive trajectory, hotel management should continue to focus on delivering exceptional guest experiences, optimizing operations, and staying responsive to changing customer demands.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Anlayze the revenue based on the distribution_channel

# Group the data by hotel and distribution_channel and calculate total revenue for each group
revenue_by_channel = df.groupby(['hotel', 'distribution_channel'])['total_revenue'].sum().reset_index()

# Create subplots for city and resort hotels
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot for city hotel
sns.barplot(x='distribution_channel', y='total_revenue', data=revenue_by_channel[revenue_by_channel['hotel'] == 'City Hotel'], ax=axes[0])
axes[0].set_xlabel('Distribution Channel')
axes[0].set_ylabel('Total Revenue')
axes[0].set_title('City Hotel')
axes[0].tick_params(axis='x', rotation=45)

# Plot for resort hotel
sns.barplot(x='distribution_channel', y='total_revenue', data=revenue_by_channel[revenue_by_channel['hotel'] == 'Resort Hotel'], ax=axes[1])
axes[1].set_xlabel('Distribution Channel')
axes[1].set_ylabel('Total Revenue')
axes[1].set_title('Resort Hotel')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the specific chart of subplots with bar charts for revenue analysis based on the distribution channel to directly compare the revenue generated by different distribution channels for both city and resort hotels side by side. This visual arrangement makes it easy to identify any disparities or patterns in revenue distribution between the two hotel types.It helps hotel managers gain valuable insights into revenue trends, identify potential areas for improvement, and make informed business decisions to optimize their revenue strategies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Travel Agency/Tour Operator (TA/TO): Both City Hotel and Resort Hotel have a higher revenue share from the TA/TO distribution channel, with City Hotel having a slightly higher percentage (1.6) compared to Resort Hotel (1.2). This indicates that travel agencies and tour operators play a significant role in driving bookings and revenue for both types of hotels.
#
# - Direct Bookings: Resort Hotel has a higher revenue share from direct bookings (below 0.4) compared to City Hotel ( 0.2). This suggests that Resort Hotel attracts a larger portion of customers who book directly with the hotel, which can lead to higher profit margins due to the absence of commission fees for third-party agents.
#
# - Corporate Bookings: Both City Hotel and Resort Hotel have relatively low revenue shares from corporate bookings (below 0.2). This insight indicates that corporate travelers might not be a significant revenue source for these hotels, and they may need to explore strategies to attract more corporate bookings to increase revenue from this segment.
#
# - Global Distribution Systems (GDS): City Hotel has a very low revenue share from GDS, suggesting that this distribution channel is not a significant source of bookings and revenue for the hotel. Resort Hotel's GDS revenue share is not mentioned explicitly, but it could be inferred as being relatively low based on the information provided.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# - Strategic Partnerships: Hotels can focus on building strong relationships with travel agencies and tour operators to enhance their revenue from this lucrative distribution channel further.
#
# - Direct Booking Promotions: Both Hotel's higher revenue from direct bookings indicates an opportunity to implement targeted marketing campaigns and loyalty programs to attract more direct bookings and potentially increase revenue.
#
# - Corporate Marketing Initiatives: Both City Hotel and Resort Hotel can invest in targeted marketing efforts to attract more corporate bookings, which could lead to increased revenue from business travelers.
#
# Negative Growth Insights:
# Based on the insights provided, there are no explicit indications of negative growth for any specific distribution channel. However, the low revenue share from certain channels, such as GDS and corporate bookings, might be considered areas for improvement. By addressing these challenges and optimizing revenue strategies, hotels can work towards reducing any potential negative impact and fostering overall growth.
#
# Overall, the gained insights can be valuable for hotel management to make data-driven decisions, optimize revenue strategies, and capitalize on the most profitable distribution channels to achieve positive business impact.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Selecting numerical columns for correlation analysis
numerical_columns = df.select_dtypes(include=[np.number])

# Calculating the correlation matrix
correlation_matrix = numerical_columns.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Columns")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the correlation heatmap chart because it allows us to visually analyze the relationships between numerical variables in the dataset. The heatmap is an effective way to display the correlation matrix, which helps us understand the strength and direction of the correlations between different variables.
#
# The correlation heatmap is particularly useful in an EDA (Exploratory Data Analysis) project because it provides a quick overview of how variables are related to each other. By looking at the heatmap, we can identify patterns and dependencies between features, which can help us make informed decisions during data analysis and modeling.
#
# the correlation heatmap is a powerful tool for gaining insights into the dataset's internal relationships and can aid in identifying key features that influence various aspects of the hotel booking analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# -  There is a positive correlation between "lead_time" and "is_canceled". This indicates that longer lead times might be associated with a higher likelihood of cancellations.
#
# - This chart also indicates that the there are high number of stay_week_nights
#
# - The number of adults in the stay_guests are more as compare to the other guests.
#
# - There is a negative correlation between the number of "total_of_special_requests" and "is_canceled". This implies that guests who make more special requests are less likely to cancel their bookings.
#
# - There is a weak positive correlation between "arrival_date_year" and "lead_time". This indicates that lead times for bookings might have slightly increased over the years.
#
# These insights help us understand the interplay between various factors in hotel bookings and can guide further analysis and decision-making in the EDA project.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called df_subset with the desired columns
# Replace 'data_columns' with the columns you want to analyze
data_columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'total_guests', 'adr', 'total_of_special_requests']

# Create the pair plot
sns.pairplot(df[data_columns])
plt.title('Pair Plot')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the Pair Plot chart because it allows for the visualization of the pairwise relationships between multiple variables in the dataset. The Pair Plot is especially useful when dealing with a relatively small number of numerical variables, as it helps us quickly understand how these variables are distributed and whether there are any obvious patterns or correlations.
#
#  the Pair Plot is a powerful tool for gaining a comprehensive understanding of the relationships between numerical variables in the dataset. It aids in identifying patterns, correlations, and potential issues, which can inform further analysis and decision-making in the hotel booking analysis project.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The lead time for most of the customers is below 300 and mostly for those who stays_in_week_nights
#
# - adr in all segments are below 1000
#
# - total_guests in each group ( including all types of guest - adults, child , babies) are less than 10
#
# - no. of guests stays in week nights is higher than no, of guest stays in weekend nights

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the insights gained from the EDA project, here are some suggestions for the client to achieve their business objectives:
#
# - Promote City Hotel's Popularity: Since City Hotels have significantly higher bookings and revenue compared to Resort Hotels, the client can capitalize on this popularity and invest more in marketing and promotions to further attract guests. Targeted marketing campaigns can be designed to showcase the unique offerings of City Hotel and reach out to potential customers.
#
# - Enhance Revenue Generation: As City Hotel's average daily rate is slightly higher, the client can explore opportunities to optimize revenue further. Dynamic pricing strategies can be implemented to maximize revenue during peak seasons and events. Additionally, creating attractive packages and offers can entice guests to choose City Hotel for their stays.
#
# - Target Online Travel Agencies: The high number of bookings from the Online TA segment presents an opportunity for the client to strengthen partnerships with online travel agencies and tour operators. Collaborating with these channels can lead to increased visibility and bookings.
#
# - Customer Experience Improvement: Understanding the preferences of guests and their reasons for cancellations can help the client enhance the overall customer experience. Special attention can be given to meeting the needs of corporate travelers and encouraging direct bookings by offering personalized experiences and loyalty rewards.
#
# - Promote Resort Hotel's Unique Offerings: To increase bookings for Resort Hotel, the client can highlight its unique features such as leisure amenities, recreational facilities, and scenic locations. Targeted marketing campaigns can attract vacationers seeking relaxation and enjoyable experiences.
#
# - Strategic Room Allocation: Since certain room types are more popular, the client can strategically allocate resources and promote the preferred room types to optimize bookings and revenue.
#
# - Manage Lead Time: The insights on lead time and cancellations can help the client manage bookings more effectively. Special offers or incentives can be provided to guests who book in advance to reduce cancellations.
#
# - Meal Plan Customization: Understanding the most popular meal plan (Bed and Breakfast) can help the client tailor their meal offerings to align with customer preferences. Offering attractive meal packages can also enhance guest satisfaction and increase bookings.
#
# - Customer Segmentation: The insights on customer preferences can help the client segment their market and create targeted marketing campaigns for different customer groups. For example, targeting business travelers with specific packages or promotions can increase bookings from this segment.
#
# - Focus on Peak Months: The client can plan marketing and promotional activities during peak months like April, May, and June to attract more guests during the popular vacation season.
#
# - Strengthening Relationships with Top Agents: The top-performing agents can be engaged in long-term partnerships, offering them incentives, or exclusive deals to continue driving high bookings.
#
# - Enhancing Direct Bookings: The client can focus on enhancing direct booking channels by offering competitive rates, special offers, and a seamless booking experience on their website.
#
# - Improve Customer Loyalty: To encourage repeat bookings and reduce cancellations, the client can introduce loyalty programs, offer rewards, or provide exclusive benefits to returning guests.
#
# - Understanding Guest Demands: To cater to the preferences of guests, the client can use the insights on stay preferences, number of guests, and special requests to customize their offerings and services.
#
# - Optimizing Stay Duration: The client can use insights on stays in week nights and weekend nights to create targeted promotions and packages for guests seeking extended stays or weekend getaways.
#
# By leveraging these insights and implementing targeted strategies, the client can improve guest satisfaction, increase bookings, optimize revenue, and achieve their business objectives. Continuous monitoring and analysis of guest preferences and market trends will further enable the client to adapt their strategies and stay competitive in the hotel industry.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Hotel Booking Analysis EDA project aimed to gain insights into the hotel booking dataset, consisting of information related to two types of hotels, City Hotel and Resort Hotel. The dataset was thoroughly analyzed and visualized to extract valuable information, which can aid in making data-driven decisions to optimize business operations and enhance customer experience.
#
# Key Insights:
#
# - Preference for City Hotel: The analysis revealed that City Hotels have a higher number of bookings, revenue, and average daily rates compared to Resort Hotels. This suggests that City Hotels are more popular among guests and attract a larger customer base.
#
# - Seasonal Variation: Both hotels experience fluctuations in guest numbers throughout the year, with August being the peak month for bookings and January being the lowest. April, May, and June also showed significant guest numbers, indicating popular vacation periods.
#
# - Guest Demographics: The analysis provided insights into the preferred meal plans, room types, and total guests for bookings. "Bed and Breakfast" meal plan and Room Type 'A' were the most popular choices among guests.
#
# - Cancellation Trends: City Hotel had a higher percentage of canceled bookings compared to Resort Hotel. Understanding the reasons behind cancellations can help in improving customer satisfaction and optimizing booking strategies.
#
# - Lead Time and Revenue: The analysis indicated that longer lead times might be associated with a higher likelihood of cancellations. Both hotels generated substantial revenue, with City Hotel's revenue slightly higher.
#
# - Distribution Channels: Travel Agency/Tour Operator was the most prominent booking distribution channel for both hotels, while direct bookings had a higher revenue share for Resort Hotel.
#
# - Customer Segmentation: Understanding customer preferences and booking patterns can enable targeted marketing efforts to cater to specific guest segments effectively.
#
# Recommendations: Based on the insights gained from the analysis, the following recommendations are made:
#
# - Marketing and Promotions: City Hotel can invest in targeted marketing campaigns to further leverage its popularity and attract more guests. Resort Hotel can focus on promoting its unique offerings, such as leisure amenities and scenic locations.
#
# - Customer Experience Enhancement: Analyzing reasons for cancellations and addressing customer concerns can help improve guest satisfaction and reduce cancellations. Personalized experiences, loyalty programs, and direct booking incentives can be introduced to enhance customer loyalty.
#
# - Strategic Partnerships: Strengthening partnerships with top-performing agents and online travel agencies can help drive more bookings and revenue for both hotels.
#
# - Seasonal Promotions: Creating targeted promotions during peak months can attract more guests during popular vacation periods and maximize revenue.
#
# - Lead Time Management: Managing lead times effectively can reduce cancellations. Offering special deals to guests who book in advance can incentivize early bookings.
#
# - Direct Bookings: Focusing on enhancing direct booking channels can lead to higher profit margins and reduce dependency on third-party agents.
#
# - Customer Segmentation Strategies: Tailoring marketing efforts for different customer segments can improve engagement and booking rates.
#
# - Customer Loyalty Programs: Implementing customer loyalty programs can encourage repeat bookings and foster a loyal customer base.
#
# - Optimize Room Allocation: Analyzing room type preferences can help optimize room allocation and pricing strategies.
#
# - Adapt to Market Trends: Continuous monitoring of market trends and customer preferences will enable the hotels to adapt their strategies and offerings to remain competitive.
#
# By implementing these recommendations, the hotel management can improve guest satisfaction, increase bookings and revenue, and establish a strong presence in the highly competitive hospitality industry.
#
# In conclusion, the Hotel Booking Analysis EDA project provided valuable insights into the dataset, helping the hotel management make data-driven decisions to enhance their business operations and customer experience. The analysis and recommendations presented in this project can serve as a foundation for further data analysis and strategic planning to achieve business objectives successfully.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
